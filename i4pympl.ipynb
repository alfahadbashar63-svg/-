# %% [markdown]
# <a href="https://colab.research.google.com/github/alfahadbashar63-svg/-/blob/main/i4pympl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Welcome to Cloud Computing Lab!")
x = 5
y = 10
print("Result:", x + y)
# Out:
# Welcome to Cloud Computing Lab!
# Result: 15

# %%
print(x*y)
# Out:
# 50
